# %%
import qrcode
from PIL import Image
import cv2

# %%
input_data = "l=100 w = 47 m=228"
#Creating an instance of qrcode
qr = qrcode.QRCode(
        version=1,
        box_size=4,
        border=0)
qr.add_data(input_data)
qr.make(fit=True)
print (qr)
img = qr.make_image(fill='black', back_color='white')
img.save('qrcode001.png')

# %%
image = cv2.imread('qrcode001.png', 0)
print(image.shape)
image = image.reshape((image.shape[0]*image.shape[1]),1)
# Out:
# (100, 100)

# %%
img

# %%
#test = [0x00,0xFF,0x00,0xFF,0x00,0xFF,0x00,0xFF,0x00,0xFF,0x00,0xFF,0x00,0xFF,0x00,0xFF,0x00,0xFF,0x00,0xFF,0x00,0xFF,0x00,0xFF,0x00,0xFF,0x00,0xFF,0x00,0xFF,0x00,0xFF,0x00,0xFF,0x00,0xFF,0x00,0xFF]
#print(len(test)%16)
#initVal = 0x00
print('shape',  image.shape[0])
if image.shape[0]%8 != 0:
    numIter = image.shape[0]//8 +1
else:
    numIter = image.shape[0]//8
print('iterations ', numIter)
valList = list()
for i in range(numIter):
    initVal = 0x00
    if i> ((image.shape[0]//8)-1):
        #print("here")
        rangeJ = image.shape[0]%8
    else:
        
        rangeJ = 8
    #print(rangeJ, i)
    for j in range(rangeJ):
        
        if image[j+(i*rangeJ)]==255:
            
            initVal = initVal|(1<<j) 
    #print(hex(initVal))
    valList.append(bin(initVal))
print(valList)
print(len(valList))
#arr = bytes(valList)
# Out:
# shape 10000
# iterations  1250
# ...

# %%
arr
# Out:
# b'
# ...

# %%
initVal = initVal|(initVal<<1) 
#initVal = 1>>3

# %%
bin(initVal)
# Out:
# '0b1111'

# %%
initVal
# Out:
# 0
